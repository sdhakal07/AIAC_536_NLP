# %% [markdown]
# ## Understanding the Pre-trained Word2Vec

# %% [markdown]
# ### Importing the libraries and modules

# %%
import gensim
from gensim.models import KeyedVectors

# %%
model = KeyedVectors.load_word2vec_format(r"GoogleNews-vectors-negative300.bin\GoogleNews-vectors-negative300.bin", binary=True)

# %% [markdown]
# ### Vocabulary size

# %%
len(model.key_to_index)
# Out:
# 3000000

# %% [markdown]
# ## Word vector size

# %%
model.vector_size
# Out:
# 300

# %% [markdown]
# ## Vocabulary

# %%
model.key_to_index
# Out:
# {'</s>': 0,
#  'in': 1,
#  'for': 2,
#  'that': 3,
#  'is': 4,
#  'on': 5,
#  '##': 6,
#  'The': 7,
#  'with': 8,
#  'said': 9,
#  'was': 10,
#  'the': 11,
#  'at': 12,
#  'not': 13,
#  'as': 14,
#  'it': 15,
#  'be': 16,
#  'from': 17,
#  'by': 18,
#  'are': 19,
#  'I': 20,
#  'have': 21,
#  'he': 22,
#  'will': 23,
#  'has': 24,
#  '####': 25,
#  'his': 26,
#  'an': 27,
#  'this': 28,
#  'or': 29,
#  'their': 30,
#  'who': 31,
#  'they': 32,
#  'but': 33,
#  '$': 34,
#  'had': 35,
#  'year': 36,
#  'were': 37,
#  'we': 38,
#  'more': 39,
#  '###': 40,
#  'up': 41,
#  'been': 42,
#  'you': 43,
#  'its': 44,
#  'one': 45,
#  'about': 46,
#  'would': 47,
#  'which': 48,
#  'out': 49,
#  'can': 50,
#  'It': 51,
#  'all': 52,
#  'also': 53,
#  'two': 54,
#  'after': 55,
#  'first': 56,
#  'He': 57,
#  'do': 58,
#  'time': 59,
#  'than': 60,
#  'when': 61,
#  'We': 62,
#  'over': 63,
#  'last': 64,
#  'new': 65,
#  'other': 66,
#  'her': 67,
#  'people': 68,
#  'into': 69,
#  'In': 70,
#  'our': 71,
#  'there': 72,
#  'A': 73,
#  'she': 74,
#  'could': 75,
#  'just': 76,
#  'years': 77,
#  'some': 78,
#  'U.S.': 79,
#  'three': 80,
#  'million': 81,
#  'them': 82,
#  'what': 83,
#  'But': 84,
#  'so': 85,
#  'no': 86,
#  'like': 87,
#  'if': 88,
#  'only': 89,
#  'percent': 90,
#  'get': 91,
#  'did': 92,
#  'him': 93,
#  'game': 94,
#  'back': 95,
#  'because': 96,
#  'now': 97,
#  '#.#': 98,
#  'before': 99,
#  'company': 100,
#  'any': 101,
#  'team': 102,
#  'against': 103,
#  'off': 104,
#  'This': 105,
#  'most': 106,
#  'made': 107,
#  'through': 108,
#  'make': 109,
#  'second': 110,
#  'state': 111,
#  'well': 112,
#  'day': 113,
#  'season': 114,
#  'says': 115,
#  'week': 116,
#  'where': 117,
#  'while': 118,
#  'down': 119,
#  'being': 120,
#  'government': 121,
#  'your': 122,
#  '#-#': 123,
#  'home': 124,
#  'going': 125,
#  'my': 126,
#  'good': 127,
#  'They': 128,
#  "'re": 129,
#  'should': 130,
#  'many': 131,
#  'way': 132,
#  'those': 133,
#  'four': 134,
#  'during': 135,
#  'such': 136,
#  'may': 137,
#  'very': 138,
#  'how': 139,
#  'since': 140,
#  'work': 141,
#  'take': 142,
#  'including': 143,
#  'high': 144,
#  'then': 145,
#  '%': 146,
#  'next': 147,
#  '#,###': 148,
#  'By': 149,
#  'much': 150,
#  'still': 151,
#  'go': 152,
#  'think': 153,
#  'old': 154,
#  'even': 155,
#  '#.##': 156,
#  'world': 157,
#  'see': 158,
#  'say': 159,
#  'business': 160,
#  'five': 161,
#  'told': 162,
#  'under': 163,
#  'us': 164,
#  '1': 165,
#  'these': 166,
#  'If': 167,
#  'right': 168,
#  'And': 169,
#  'me': 170,
#  'between': 171,
#  'play': 172,
#  'help': 173,
#  '##,###': 174,
#  'market': 175,
#  'That': 176,
#  'know': 177,
#  'end': 178,
#  'AP': 179,
#  'long': 180,
#  'information': 181,
#  'points': 182,
#  'does': 183,
#  'both': 184,
#  'There': 185,
#  'part': 186,
#  'around': 187,
#  'police': 188,
#  'want': 189,
#  "'ve": 190,
#  'based': 191,
#  'For': 192,
#  'got': 193,
#  'third': 194,
#  'school': 195,
#  'left': 196,
#  'another': 197,
#  'country': 198,
#  'need': 199,
#  '2': 200,
#  'best': 201,
#  'win': 202,
#  'quarter': 203,
#  'use': 204,
#  'today': 205,
#  '##.#': 206,
#  'same': 207,
#  'public': 208,
#  'run': 209,
#  'Friday': 210,
#  'set': 211,
#  'month': 212,
#  'top': 213,
#  'billion': 214,
#  'Tuesday': 215,
#  'come': 216,
#  'Monday': 217,
#  'She': 218,
#  'city': 219,
#  'place': 220,
#  'night': 221,
#  'six': 222,
#  'each': 223,
#  'Thursday': 224,
#  '###,###': 225,
#  'Wednesday': 226,
#  'here': 227,
#  'You': 228,
#  'group': 229,
#  'really': 230,
#  'found': 231,
#  'As': 232,
#  'used': 233,
#  '3': 234,
#  'lot': 235,
#  "'m": 236,
#  'money': 237,
#  'put': 238,
#  'games': 239,
#  'support': 240,
#  'program': 241,
#  'half': 242,
#  'report': 243,
#  'family': 244,
#  'months': 245,
#  'number': 246,
#  'officials': 247,
#  'am': 248,
#  'former': 249,
#  'own': 250,
#  'man': 251,
#  'Saturday': 252,
#  'too': 253,
#  'better': 254,
#  'days': 255,
#  'came': 256,
#  'lead': 257,
#  'life': 258,
#  'American': 259,
#  '##-##': 260,
#  'show': 261,
#  'past': 262,
#  'took': 263,
#  'added': 264,
#  'expected': 265,
#  'called': 266,
#  'great': 267,
#  'State': 268,
#  'services': 269,
#  'children': 270,
#  'hit': 271,
#  'area': 272,
#  'system': 273,
#  'every': 274,
#  'pm': 275,
#  'big': 276,
#  'service': 277,
#  'few': 278,
#  'per': 279,
#  'members': 280,
#  'Sunday': 281,
#  'early': 282,
#  'point': 283,
#  'start': 284,
#  'companies': 285,
#  'little': 286,
#  '&': 287,
#  'case': 288,
#  'ago': 289,
#  'local': 290,
#  'according': 291,
#  'never': 292,
#  '5': 293,
#  'without': 294,
#  'sales': 295,
#  'until': 296,
#  'went': 297,
#  'players': 298,
#  '##th': 299,
#  'New_York': 300,
#  'won': 301,
#  'financial': 302,
#  'news': 303,
#  '4': 304,
#  'When': 305,
#  'share': 306,
#  'several': 307,
#  'free': 308,
#  'away': 309,
#  '##.##': 310,
#  'already': 311,
#  'On': 312,
#  'industry': 313,
#  "'ll": 314,
#  'call': 315,
#  'With': 316,
#  'students': 317,
#  'line': 318,
#  'available': 319,
#  'County': 320,
#  'making': 321,
#  'held': 322,
#  'final': 323,
#  '#:##': 324,
#  'power': 325,
#  'plan': 326,
#  'might': 327,
#  'least': 328,
#  'look': 329,
#  'forward': 330,
#  'give': 331,
#  'At': 332,
#  'again': 333,
#  'later': 334,
#  'full': 335,
#  'must': 336,
#  'things': 337,
#  'major': 338,
#  'community': 339,
#  'announced': 340,
#  'open': 341,
#  'record': 342,
#  'reported': 343,
#  'court': 344,
#  'working': 345,
#  'able': 346,
#  'something': 347,
#  'president': 348,
#  'meeting': 349,
#  'keep': 350,
#  'March': 351,
#  'future': 352,
#  'far': 353,
#  'deal': 354,
#  'City': 355,
#  'May': 356,
#  'development': 357,
#  'University': 358,
#  'find': 359,
#  'times': 360,
#  'After': 361,
#  'office': 362,
#  'led': 363,
#  'among': 364,
#  'June': 365,
#  'increase': 366,
#  'China': 367,
#  'John': 368,
#  'whether': 369,
#  'cost': 370,
#  'security': 371,
#  'job': 372,
#  'less': 373,
#  'head': 374,
#  'seven': 375,
#  'growth': 376,
#  'lost': 377,
#  'pay': 378,
#  'looking': 379,
#  'provide': 380,
#  '6': 381,
#  'To': 382,
#  'plans': 383,
#  'products': 384,
#  'car': 385,
#  'recent': 386,
#  'hard': 387,
#  'always': 388,
#  'include': 389,
#  'women': 390,
#  'across': 391,
#  'tax': 392,
#  'water': 393,
#  'April': 394,
#  'continue': 395,
#  'important': 396,
#  'different': 397,
#  'close': 398,
#  '7': 399,
#  'One': 400,
#  'late': 401,
#  'decision': 402,
#  'current': 403,
#  'law': 404,
#  'within': 405,
#  'along': 406,
#  'played': 407,
#  'move': 408,
#  'United_States': 409,
#  'enough': 410,
#  'become': 411,
#  'side': 412,
#  'national': 413,
#  'Inc.': 414,
#  'results': 415,
#  'level': 416,
#  'loss': 417,
#  'economic': 418,
#  'coach': 419,
#  'near': 420,
#  'getting': 421,
#  'price': 422,
#  'Department': 423,
#  'event': 424,
#  'fourth': 425,
#  'change': 426,
#  'All': 427,
#  'small': 428,
#  'board': 429,
#  'National': 430,
#  'So': 431,
#  'goal': 432,
#  'taken': 433,
#  'field': 434,
#  'prices': 435,
#  'weeks': 436,
#  'men': 437,
#  'asked': 438,
#  'eight': 439,
#  'data': 440,
#  'shot': 441,
#  'New': 442,
#  'started': 443,
#  'July': 444,
#  'director': 445,
#  'President': 446,
#  'party': 447,
#  'federal': 448,
#  'done': 449,
#  'political': 450,
#  'minutes': 451,
#  'taking': 452,
#  'Company': 453,
#  'technology': 454,
#  'project': 455,
#  'center': 456,
#  'leading': 457,
#  'issue': 458,
#  'though': 459,
#  'having': 460,
#  'period': 461,
#  'likely': 462,
#  'scored': 463,
#  '8': 464,
#  'strong': 465,
#  'series': 466,
#  'military': 467,
#  'seen': 468,
#  'trying': 469,
#  'What': 470,
#  'coming': 471,
#  'process': 472,
#  'building': 473,
#  'behind': 474,
#  'performance': 475,
#  'management': 476,
#  'Iraq': 477,
#  'saying': 478,
#  'earlier': 479,
#  'believe': 480,
#  'oil': 481,
#  'given': 482,
#  'Police': 483,
#  'customers': 484,
#  'due': 485,
#  'following': 486,
#  'term': 487,
#  'others': 488,
#  'statement': 489,
#  'international': 490,
#  'economy': 491,
#  'health': 492,
#  'thing': 493,
#  'Obama': 494,
#  'return': 495,
#  'killed': 496,
#  'Washington': 497,
#  'further': 498,
#  'However': 499,
#  'doing': 500,
#  'face': 501,
#  'low': 502,
#  'higher': 503,
#  'site': 504,
#  'once': 505,
#  'yet': 506,
#  'hours': 507,
#  'America': 508,
#  'control': 509,
#  'received': 510,
#  'rate': 511,
#  'career': 512,
#  'Bush': 513,
#  'teams': 514,
#  'known': 515,
#  'offer': 516,
#  'race': 517,
#  'ever': 518,
#  'experience': 519,
#  'playing': 520,
#  'name': 521,
#  'possible': 522,
#  'countries': 523,
#  'Mr.': 524,
#  'average': 525,
#  'together': 526,
#  'using': 527,
#  '9': 528,
#  'cut': 529,
#  'While': 530,
#  'total': 531,
#  'round': 532,
#  'young': 533,
#  'nearly': 534,
#  'shares': 535,
#  'member': 536,
#  'campaign': 537,
#  'media': 538,
#  'needs': 539,
#  'why': 540,
#  'house': 541,
#  'issues': 542,
#  'costs': 543,
#  'fire': 544,
#  '##-#': 545,
#  'victory': 546,
#  'player': 547,
#  'began': 548,
#  'sure': 549,
#  'story': 550,
#  'per_cent': 551,
#  'North': 552,
#  'His': 553,
#  'staff': 554,
#  'order': 555,
#  'war': 556,
#  'large': 557,
#  'interest': 558,
#  'stock': 559,
#  'food': 560,
#  'research': 561,
#  'key': 562,
#  'India': 563,
#  'South': 564,
#  'morning': 565,
#  'conference': 566,
#  'senior': 567,
#  'global': 568,
#  'Center': 569,
#  'death': 570,
#  'person': 571,
#  'thought': 572,
#  'gave': 573,
#  'feel': 574,
#  'energy': 575,
#  'history': 576,
#  'recently': 577,
#  'largest': 578,
#  'No.': 579,
#  'general': 580,
#  'official': 581,
#  'released': 582,
#  'wanted': 583,
#  'meet': 584,
#  'short': 585,
#  'outside': 586,
#  'running': 587,
#  'live': 588,
#  'ball': 589,
#  'online': 590,
#  'real': 591,
#  'position': 592,
#  'fact': 593,
#  'fell': 594,
#  'nine': 595,
#  'December': 596,
#  'front': 597,
#  'action': 598,
#  'defense': 599,
#  'problem': 600,
#  'problems': 601,
#  'Mr': 602,
#  'nation': 603,
#  'needed': 604,
#  'special': 605,
#  'January': 606,
#  'almost': 607,
#  'chance': 608,
#  "'d": 609,
#  'result': 610,
#  'West': 611,
#  'September': 612,
#  'reports': 613,
#  'leader': 614,
#  'investment': 615,
#  'yesterday': 616,
#  'Some': 617,
#  'leaders': 618,
#  'ahead': 619,
#  'production': 620,
#  'comes': 621,
#  'No': 622,
#  'runs': 623,
#  'match': 624,
#  'role': 625,
#  'kind': 626,
#  'try': 627,
#  'ended': 628,
#  'risk': 629,
#  'areas': 630,
#  'election': 631,
#  'workers': 632,
#  'visit': 633,
#  'bring': 634,
#  'road': 635,
#  'music': 636,
#  'study': 637,
#  'makes': 638,
#  'often': 639,
#  'release': 640,
#  'woman': 641,
#  'vote': 642,
#  'care': 643,
#  'town': 644,
#  'clear': 645,
#  'comment': 646,
#  'budget': 647,
#  'potential': 648,
#  'single': 649,
#  'markets': 650,
#  'policy': 651,
#  'capital': 652,
#  'saw': 653,
#  'access': 654,
#  'weekend': 655,
#  'operations': 656,
#  'whose': 657,
#  'net': 658,
#  'House': 659,
#  'hand': 660,
#  'increased': 661,
#  'charges': 662,
#  'winning': 663,
#  'trade': 664,
#  'These': 665,
#  'income': 666,
#  'value': 667,
#  'involved': 668,
#  'Bank': 669,
#  'November': 670,
#  'bill': 671,
#  'compared': 672,
#  'anything': 673,
#  'manager': 674,
#  'Texas': 675,
#  'property': 676,
#  'stop': 677,
#  'annual': 678,
#  'private': 679,
#  'contract': 680,
#  'died': 681,
#  'Now': 682,
#  'hope': 683,
#  'product': 684,
#  'fans': 685,
#  'lower': 686,
#  'demand': 687,
#  'News': 688,
#  'David': 689,
#  'club': 690,
#  'comments': 691,
#  'film': 692,
#  'yards': 693,
#  'quality': 694,
#  'currently': 695,
#  'events': 696,
#  'addition': 697,
#  'couple': 698,
#  'schools': 699,
#  'attack': 700,
#  'region': 701,
#  'latest': 702,
#  'opportunity': 703,
#  'worked': 704,
#  'course': 705,
#  'bad': 706,
#  'fall': 707,
#  'Group': 708,
#  'October': 709,
#  'jobs': 710,
#  'list': 711,
#  'let': 712,
#  'however': 713,
#  'chief': 714,
#  'summer': 715,
#  'programs': 716,
#  'According': 717,
#  'revenue': 718,
#  'Our': 719,
#  'rose': 720,
#  'previous': 721,
#  'TV': 722,
#  'football': 723,
#  'biggest': 724,
#  'employees': 725,
#  'changes': 726,
#  'residents': 727,
#  'means': 728,
#  'agreement': 729,
#  'includes': 730,
#  'post': 731,
#  'Canada': 732,
#  'probably': 733,
#  'related': 734,
#  'training': 735,
#  'allowed': 736,
#  'class': 737,
#  'bit': 738,
#  'video': 739,
#  'Michael': 740,
#  'An': 741,
#  'sent': 742,
#  'education': 743,
#  'states': 744,
#  'straight': 745,
#  'love': 746,
#  'beat': 747,
#  'hold': 748,
#  'turn': 749,
#  'finished': 750,
#  'network': 751,
#  'Smith': 752,
#  'buy': 753,
#  'foreign': 754,
#  'especially': 755,
#  'groups': 756,
#  'wants': 757,
#  'title': 758,
#  'included': 759,
#  'turned': 760,
#  'bank': 761,
#  'Florida': 762,
#  'efforts': 763,
#  'personal': 764,
#  'businesses': 765,
#  'August': 766,
#  'California': 767,
#  'situation': 768,
#  'district': 769,
#  'allow': 770,
#  'helped': 771,
#  'body': 772,
#  'nothing': 773,
#  'soon': 774,
#  'safety': 775,
#  'officer': 776,
#  'cents': 777,
#  'Europe': 778,
#  'St.': 779,
#  'additional': 780,
#  'spokesman': 781,
#  'February': 782,
#  'wife': 783,
#  'showed': 784,
#  'leave': 785,
#  'investors': 786,
#  'parents': 787,
#  'medical': 788,
#  'spending': 789,
#  'non': 790,
#  'London': 791,
#  'Council': 792,
#  'matter': 793,
#  'spent': 794,
#  'child': 795,
#  'World': 796,
#  'effort': 797,
#  'opening': 798,
#  'either': 799,
#  'range': 800,
#  'question': 801,
#  'European': 802,
#  'goals': 803,
#  'administration': 804,
#  'friends': 805,
#  'himself': 806,
#  'shows': 807,
#  'difficult': 808,
#  'kids': 809,
#  'paid': 810,
#  'create': 811,
#  'cash': 812,
#  'age': 813,
#  'league': 814,
#  'form': 815,
#  'impact': 816,
#  'drive': 817,
#  'someone': 818,
#  'became': 819,
#  'stay': 820,
#  'fight': 821,
#  'significant': 822,
#  'firm': 823,
#  'Senate': 824,
#  'hospital': 825,
#  'charged': 826,
#  'operating': 827,
#  'main': 828,
#  'book': 829,
#  'success': 830,
#  'son': 831,
#  'trading': 832,
#  '###-####': 833,
#  'focus': 834,
#  'room': 835,
#  'continued': 836,
#  'Congress': 837,
#  'everything': 838,
#  'Park': 839,
#  'agency': 840,
#  'brought': 841,
#  'talk': 842,
#  'break': 843,
#  'air': 844,
#  'software': 845,
#  'decided': 846,
#  'Do': 847,
#  'ready': 848,
#  'arrested': 849,
#  'track': 850,
#  'provides': 851,
#  'mother': 852,
#  'base': 853,
#  'trial': 854,
#  'phone': 855,
#  'My': 856,
#  'build': 857,
#  'conditions': 858,
#  'rest': 859,
#  'Johnson': 860,
#  'terms': 861,
#  'expect': 862,
#  'England': 863,
#  'Israel': 864,
#  'despite': 865,
#  'closed': 866,
#  'starting': 867,
#  'provided': 868,
#  'pressure': 869,
#  'lives': 870,
#  'step': 871,
#  'remain': 872,
#  'similar': 873,
#  'charge': 874,
#  'date': 875,
#  'whole': 876,
#  'land': 877,
#  'growing': 878,
#  'James': 879,
#  'Internet': 880,
#  'projects': 881,
#  'British': 882,
#  'cases': 883,
#  'ground': 884,
#  'legal': 885,
#  'International': 886,
#  'agreed': 887,
#  'tell': 888,
#  'test': 889,
#  'everyone': 890,
#  'pretty': 891,
#  'authorities': 892,
#  'Two': 893,
#  'above': 894,
#  'moved': 895,
#  'profit': 896,
#  'throughout': 897,
#  'inside': 898,
#  'ability': 899,
#  'overall': 900,
#  'pass': 901,
#  'officers': 902,
#  'rather': 903,
#  'Australia': 904,
#  'actually': 905,
#  'county': 906,
#  'amount': 907,
#  'scheduled': 908,
#  'themselves': 909,
#  'organization': 910,
#  'giving': 911,
#  'credit': 912,
#  'father': 913,
#  'drug': 914,
#  'investigation': 915,
#  'families': 916,
#  'Republican': 917,
#  'funds': 918,
#  'patients': 919,
#  'takes': 920,
#  'systems': 921,
#  'Japan': 922,
#  'complete': 923,
#  'sold': 924,
#  'practice': 925,
#  'calls': 926,
#  '•': 927,
#  'UK': 928,
#  'force': 929,
#  'student': 930,
#  'idea': 931,
#  'reached': 932,
#  'reason': 933,
#  'levels': 934,
#  'space': 935,
#  'competition': 936,
#  'forces': 937,
#  'sector': 938,
#  'Last': 939,
#  'tried': 940,
#  'common': 941,
#  'homes': 942,
#  'stage': 943,
#  'department': 944,
#  'named': 945,
#  'earnings': 946,
#  'offers': 947,
#  'star': 948,
#  'certain': 949,
#  'double': 950,
#  'longer': 951,
#  'followed': 952,
#  'cause': 953,
#  'Association': 954,
#  'signed': 955,
#  'committee': 956,
#  'hour': 957,
#  'college': 958,
#  'Pakistan': 959,
#  'users': 960,
#  'Iran': 961,
#  'sign': 962,
#  'living': 963,
#  'failed': 964,
#  'reach': 965,
#  'quickly': 966,
#  'receive': 967,
#  'debt': 968,
#  'sale': 969,
#  'Board': 970,
#  'Americans': 971,
#  'Road': 972,
#  'Brown': 973,
#  'insurance': 974,
#  '##:##': 975,
#  'anyone': 976,
#  'tournament': 977,
#  'More': 978,
#  'gas': 979,
#  'talks': 980,
#  'serious': 981,
#  'required': 982,
#  'sell': 983,
#  'construction': 984,
#  'evidence': 985,
#  'remains': 986,
#  'black': 987,
#  'below': 988,
#  'improve': 989,
#  'crisis': 990,
#  'address': 991,
#  'questions': 992,
#  'easy': 993,
#  'begin': 994,
#  'view': 995,
#  'School': 996,
#  'heard': 997,
#  'executive': 998,
#  'raised': 999,
#  ...}

# %% [markdown]
# ## Summary
#
# In this assignment we used gensim library and loaded google news vector to pre-trained Word2Vec models.After loading vector to pretrained model we look into  v size and vocabulary
# # 1 Gensim:
# This library, specifically the KeyedVectors module, is used for loading and working with pre-trained Word2Vec models.
